-- %%
SELECT 
TOP 20 InvoiceDate
, PaymentDate
, InvoiceTotal
, PaymentTotal
FROM
Invoices
WHERE InvoiceTotal
BETWEEN (6) 
AND (95)
-- Out:
-- (20 rows affected)
-- Total execution time: 00:00:00.004
-- ...
